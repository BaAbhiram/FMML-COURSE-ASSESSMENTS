# %% [markdown]
# <a href="https://colab.research.google.com/github/BaAbhiram/FMML-COURSE-ASSESSMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 14:49:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   120MB/s    in 0.6s
#
# 2023-05-03 14:49:54 (120 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 253  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3660   1508.06161v1  We present a unified framework which supports ...    cs
# 10535   1207.3438v1  Non-negative matrix factorization (NMF) approx...  stat
# 22936  1711.03431v1  One iteration of $k$-means or EM for Gaussian ...  stat
# 12528  1802.07513v1  Classification problems in security settings a...  stat
# 9663   1601.08165v1  Diffusion magnetic resonance imaging (dMRI) an...  stat
# ...             ...                                                ...   ...
# 34361  1602.03551v1  Identifying relationships between concepts is ...    cs
# 3778    1404.3012v5  This paper presents a Bayesian image segmentat...    cs
# 4152   1606.02556v5  We present a new type of probabilistic model w...    cs
# 7260   1711.05374v1  Building highly non-linear and non-parametric ...  stat
# 23709   1104.0579v1  This report presents the results and details o...    cs
#
#                                                    title  year  \
# 3660   Robot Language Learning, Generation, and Compr...  2015
# 10535  MahNMF: Manhattan Non-negative Matrix Factoriz...  2012
# 22936  Can clustering scale sublinearly with its clus...  2017
# 12528  Adversarial classification: An adversarial ris...  2018
# 9663                Mapping Tractography Across Subjects  2016
# ...                                                  ...   ...
# 34361  Knowledge Transfer with Medical Language Embed...  2016
# 3778   Bayesian image segmentations by Potts prior an...  2014
# 4152      DISCO Nets: DISsimilarity COefficient Networks  2016
# 7260      Optimizing Kernel Machines using Deep Learning  2017
# 23709   Image Retrieval Method Using Top-surf Descriptor  2011
#
#                                                 keywords
# 3660   [framework, grounding, semantics, framework, a...
# 10535  [factorization, approximates, extensions, dive...
# 22936  [iteration, dimensionality, iteration, subline...
# 12528  [classification, contemplated, confrontations,...
# 9663   [diffusion, resonance, tractography, anatomica...
# ...                                                  ...
# 34361  [identifying, relationships, scientific, knowl...
# 3778   [segmentation, propagation, including, interac...
# 4152   [probabilistic, dissimilarity, coefficient, ef...
# 7260   [parametric, important, techniques, reproducin...
# 23709  [retrieval, descriptor, experimental, prelimin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3660     [framework, grounding, semantics, framework, a...
# 10535    [factorization, approximates, extensions, dive...
# 22936    [iteration, dimensionality, iteration, subline...
# 12528    [classification, contemplated, confrontations,...
# 9663     [diffusion, resonance, tractography, anatomica...
#                                ...
# 22720    [promising, parameters, differential, equation...
# 6657     [association, alzheimers, collaborative, diffe...
# 22900    [considers, classification, connectome, connec...
# 21619    [properties, frequently, depending, situations...
# 31337    [architecture, expressive, essentially, mathem...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8737 words.
# Out of those 4588 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dcd83318-1185-4e04-ad5c-01289ce207db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcd83318-1185-4e04-ad5c-01289ce207db")) {                    Plotly.newPlot(                        "dcd83318-1185-4e04-ad5c-01289ce207db",                        [{"x":["sentential","description","performance","grounding","automated","annotation","generation","correctness","specified","accomplish","independent","prepositions","associated","achieving","completeness","sentences","comprehension","framework","acquisition","navigational","semantics","optimization","contaminated","distribution","functions","estimates","constrained","algorithms","laplacian","manhattan","symmetric","inversely","regularized","proportional","nesterovs","approximation","divergence","factorization","iteratively","extensions","approximating","recursively","particular","applications","parameter","objective","approximates","effectively","minimizes","euclidean","practical","smoothing","efficient","contribution","developing","decompositions","iteration","comparable","theoretical","clustering","typically","substantial","reduction","dependency","generally","magnitude","reductions","tractable","exponentially","consequently","relationship","complexity","sublinear","truncated","effective","dimensionality","acceleration","variational","empirical","computational","observation","generative","neighborhood","iterations","implementation","assumptions","discussed","classifier","illustrate","adversaries","classification","alternative","approaches","realistic","adversarial","knowledge","underlying","combinatorial","registration","segmentation","anatomical","annealing","streamline","techniques","implemented","differences","similarities","structures","resonance","necessary","tractographies","specifically","performed","tractography","resulting","diffusion","volumetric","reformulate","simulated","transform","preliminary","promising","correspond","transformation","forecasting","vulnerabilities","integrated","historical","different","resources","forecasts","forecasted","subsequent","nonstationarity","conditions","processing","nonlinear","effectiveness","determines","numerical","radiation","including","highlighting","renewable","simulations","accordingly","importance","increased","classical","regarding","individual","statistical","additional","supervised","popularity","discretized","established","autonomous","algorithmic","predictions","dynamical","information","dimensional","functional","challenge","heterogeneity","structure","successful","presented","application","discriminant","unsupervised","considered","illustrated","available","traditionally","exploratory","difficulties","multivariate","prevalence","increasing","brightness","physiology","chromaticity","perception","discussion","literature","interpretation","reflection","following","community","objectives","facilitate","comprehensive","luminance","subjective","fundamental","background","frequency","developed"],"y":[2,81,900,12,103,69,138,17,34,16,138,2,112,62,13,59,14,528,50,2,120,329,8,190,216,84,60,579,18,2,25,2,47,10,2,103,16,38,37,40,19,5,305,453,114,169,8,117,12,23,135,17,383,77,64,12,45,97,148,135,99,41,86,40,68,47,8,33,14,31,70,233,6,7,223,38,16,59,146,288,61,119,26,26,129,58,60,138,81,4,482,78,474,62,103,357,112,49,32,193,9,9,0,369,94,57,37,142,10,80,0,173,109,0,172,13,14,7,69,63,43,114,28,52,20,3,47,21,720,73,4,1,26,1,136,287,43,225,13,83,6,223,9,2,37,19,91,32,100,40,122,143,131,199,16,6,51,67,42,77,14,699,175,32,152,5,350,68,170,253,8,126,131,20,324,19,2,32,16,8,107,8,5,2,41,18,115,53,7,88,79,35,44,70,4,24,92,56,51,202],"type":"bar"},{"x":["sentential","description","performance","grounding","automated","annotation","generation","correctn ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4588,), (4588, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>(Anti)Conditional</span> <span style='background-color:rgba(255, 0, 0, 0.43902439024390255);'>Independence</span> <span style=''>in</span> <span style=''>Dempster</span> <span style=''>Shafer</span> <span style=''>Theory</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>verifies</span> <span style=''>a</span> <span style=''>result</span> <span style=''>of</span> <span style=''>Shenoy94</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740744);'>concerning</span> <span style=''>graphoidal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>Shenoys</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43902439024390255);'>independence</span> <span style=''>for</span> <span style=''>Dempster</span> <span style=''>Shafer</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>Shenoy</span> <span style=''>proved</span> <span style=''>that</span> <span style=''>his</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43902439024390255);'>independence</span> <span style=''>has</span> <span style=''>graphoidal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>for</span> <span style=''>positive</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>valuations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirement</span> <span style=''>of</span> <span style=''>strict</span> <span style=''>positive</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>valuations</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>prerequisite</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>graphoidal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>excludes</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>class</span> <span style=''>of</span> <span style=''>DS</span> <span style=''>belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>It</span> <span style=''>excludes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirement</span> <span style=''>of</span> <span style=''>positiveness</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>valuation</span> <span style=''>may</span> <span style=''>be</span> <span style=''>weakened</span> <span style=''>in</span> <span style=''>that</span> <span style=''>it</span> <span style=''>may</span> <span style=''>be</span> <span style=''>required</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>commonality</span> <span style=''>function</span> <span style=''>is</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>singleton</span> <span style=''>sets</span> <span style=''>instead</span> <span style=''>and</span> <span style=''>the</span> <span style=''>graphoidal</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Differential</span> <span style=''>Privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Learnability</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sufficiency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Necessity</span> <span style=''>of</span> <span style=''>ERM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Principle</span> <br/><br/><span style=''>While</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>many</span> <span style=''>real</span> <span style=''>life</span> <span style=''>problems</span> <span style=''>its</span> <span style=''>use</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>domains</span> <span style=''>has</span> <span style=''>been</span> <span style=''>limited</span> <span style=''>due</span> <span style=''>to</span> <span style=''>privacy</span> <span style=''>concerns</span> <span style=''>A</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>known</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>privacy</span> <span style=''>offers</span> <span style=''>provable</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>but</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style=''>observed</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>that</span> <span style=''>it</span> <span style=''>could</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantially</span> <span style=''>hamper</span> <span style=''>learning</span> <span style=''>accuracy</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learnability</span> <span style=''>(whether</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learned</span> <span style=''>by</span> <span style=''>any</span> <span style=''>algorithm)</span> <span style=''>under</span> <span style=''>Vapniks</span> <span style=''>general</span> <span style=''>learning</span> <span style=''>setting</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>and</span> <span style=''>reveal</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intricate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learnability</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>privately</span> <span style='background-color:rgba(255, 0, 0, 0.3); ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Performing</span> <span style=''>Bayesian</span> <span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Aggregation</span> <span style=''>using</span> <span style=''>Discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>with</span> <span style=''>Graph</span> <span style='background-color:rgba(255, 0, 0, 0.39199999999999996);'>Factorization</span> <br/><br/><span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>method</span> <span style=''>used</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>financial</span> <span style=''>assets</span> <span style=''>or</span> <span style=''>events</span> <span style=''>where</span> <span style=''>each</span> <span style=''>asset</span> <span style=''>or</span> <span style=''>event</span> <span style=''>is</span> <span style=''>modelled</span> <span style=''>as</span> <span style=''>a</span> <span style=''>random</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>financial</span> <span style=''>services</span> <span style=''>industry</span> <span style=''>include</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>insurance</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157894);'>operational</span> <span style=''>risk</span> <span style=''>stress</span> <span style=''>testing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitivity</span> <span style=''>analysis</span> <span style=''>but</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>widely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>in</span> <span style=''>many</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>domains</span> <span style=''>This</span> <span style=''>thesis</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributed</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>Bayesian</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>when</span> <span style=''>model</span> <span style=''>exhibit</span> <span style=''>hybrid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.39655172413793105);'>dimensional</span> <span style=''>inter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>operates</span> <span style=''>on</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>general</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>an</span> <span style=''>emphasis</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.5094339622641508);'>convolution</span> <span style=''>problems</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Jitter</span> <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Multi</span> <span style=''>Trial</span> <span style=''>Neuroelectric</span> <span style=''>Signals</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>many</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>tasks</span> <span style=''>where</span> <span style=''>atoms</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>small</span> <span style=''>image</span> <span style=''>patches</span> <span style=''>As</span> <span style=''>a</span> <span style=''>drawback</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>only</span> <span style=''>encodes</span> <span style=''>basic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>treats</span> <span style=''>patches</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>in</span> <span style=''>one</span> <span style=''>single</span> <span style=''>set</span> <span style=''>which</span> <span style=''>means</span> <span style=''>a</span> <span style=''>loss</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>when</span> <span style=''>features</span> <span style=''>are</span> <span style=''>well</span> <span style=''>aligned</span> <span style=''>across</span> <span style=''>signals</span> <span style=''>This</span> <span style=''>is</span> <span style=''>the</span> <span style=''>case</span> <span style=''>for</span> <span style=''>instance</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>trial</span> <span style=''>magneto</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>electroencephalography</span> <span style=''>(MEEG)</span> <span style=''>Learning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>on</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>signals</span> <span style=''>could</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>alignement</span> <span style=''>and</span> <span style=''>reveal</span> <span style=''>higher</span> <span style=''>level</span> <span style=''>features</span> <span style=''>In</span> <span style=''>this</span> <span style=''>case</span> <span style=''>however</span> <span style=''>small</span> <span style=''>missalignements</span> <span style=''>or</span> <span style=''>phase</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>of</span> <span style=''>features</span> <span style=''>would</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compensated</span> <span style=''>for</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='backg ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05440967283072546)
# 	knowledge (0.12695590327169273)
# 	architecture (0.08926031294452347)
# 	segmentation (0.06863442389758179)
# 	representation (0.13051209103840683)
# 	detection (0.12019914651493599)
# 	information (0.24857752489331436)
# 	different (0.25604551920341395)
# 	recognition (0.14118065433854907)
# 	convolutional (0.15256045519203415)
#
# Some Statistics words are:
# 	theoretical (0.14839034205231388)
# 	stochastic (0.1398390342052314)
# 	variables (0.1488933601609658)
# 	statistical (0.15543259557344064)
# 	distribution (0.176056338028169)
# 	estimation (0.17857142857142858)
# 	algorithm (0.39235412474849096)
# 	inference (0.20372233400402415)
# 	dimensional (0.20372233400402415)
# 	regression (0.1846076458752515)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b2ce8745-1fae-492d-af5d-beacac87302e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2ce8745-1fae-492d-af5d-beacac87302e")) {                    Plotly.newPlot(                        "b2ce8745-1fae-492d-af5d-beacac87302e",                        [{"x":["sentential","description","performance","grounding","automated","annotation","generation","correctness","specified","accomplish","independent","prepositions","associated","achieving","completeness","sentences","comprehension","framework","acquisition","navigational","semantics","optimization","contaminated","distribution","functions","estimates","constrained","algorithms","laplacian","manhattan","symmetric","inversely","regularized","proportional","nesterovs","approximation","divergence","factorization","iteratively","extensions","approximating","recursively","particular","applications","parameter","objective","approximates","effectively","minimizes","euclidean","practical","smoothing","efficient","contribution","developing","decompositions","iteration","comparable","theoretical","clustering","typically","substantial","reduction","dependency","generally","magnitude","reductions","tractable","exponentially","consequently","relationship","complexity","sublinear","truncated","effective","dimensionality","acceleration","variational","empirical","computational","observation","generative","neighborhood","iterations","implementation","assumptions","discussed","classifier","illustrate","adversaries","classification","alternative","approaches","realistic","adversarial","knowledge","underlying","combinatorial","registration","segmentation","anatomical","annealing","streamline","techniques","implemented","differences","similarities","structures","resonance","necessary","tractographies","specifically","performed","tractography","resulting","diffusion","volumetric","reformulate","simulated","transform","preliminary","promising","correspond","transformation","forecasting","vulnerabilities","integrated","historical","different","resources","forecasts","forecasted","subsequent","nonstationarity","conditions","processing","nonlinear","effectiveness","determines","numerical","radiation","including","highlighting","renewable","simulations","accordingly","importance","increased","classical","regarding","individual","statistical","additional","supervised","popularity","discretized","established","autonomous","algorithmic","predictions","dynamical","information","dimensional","functional","challenge","heterogeneity","structure","successful","presented","application","discriminant","unsupervised","considered","illustrated","available","traditionally","exploratory","difficulties","multivariate","prevalence","increasing","brightness","physiology","chromaticity","perception","discussion","literature","interpretation","reflection","following","community","objectives","facilitate","comprehensive","luminance","subjective","fundamental","background","frequency","developed","appropriate","sensitive","interactions","conceptual","behavioral","significantly","convolutional","recognition","supervision","therefore","collecting","retrained","personalized","likelihood","comparing","foundation","precursory","relevance","baselines","evaluation","demonstrate","leveraging","attention","conditioned","decisions","improvements","understanding","extraction","prototype","recurrent","recommendation","significant","identification","uncertainty","interaction","questions","intention","submitted","estimation","benchmarks","introduces","procedure","collection","benchmark","constraint","solutions","instances","combining","dedicated","algorithm","diagnostics","activated","experiments","coincides","suggesting","iterative","describing","t ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	streamline
# 	tractographies
# 	tractography
# 	coincides
# 	oscillates
# 	looseness
# 	cigarette
# 	respiration
# 	actigraphy
# 	faithfulness
# 	astrophysics
# 	horseshoe
# 	polarimetric
# 	tibshirani
# 	blockwise
# 	stragglers
# 	sociology
# 	catalogue
# 	permutations
# 	kleinberg
# Some words which never appear in Statistics papers:
# 	sentential
# 	prepositions
# 	navigational
# 	physiology
# 	chromaticity
# 	reflection
# 	luminance
# 	retrained
# 	replicates
# 	assistant
# 	connectionist
# 	mirroring
# 	morphogenesis
# 	commitment
# 	symbiotic
# 	reinforced
# 	occlusions
# 	registering
# 	galleries
# 	summarizes

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.057355998532469e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
